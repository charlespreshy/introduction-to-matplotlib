# %% [markdown]
# ### Introduction to matplotlib
#
# Matplotlib is one of the most popular Python packages used for data visualisation. It is a cross-platform library for making 2D plots from data in arrays. It provides an object-oriented API that helps in embeddig plots in applications using python.
#
# It works together with Numpy to build Graphical Representation for data.
#
# The major modules of the matplotlib library used for plotting graphs is the pyplot.
#
# Matplotlib.pyplot is a collection of command style functions that make Matplotlib work like MATLAB. Each pyplot function makes some change to a figure. For example, a function creates a figure, a plotting area in a figure, plots some lines in a plotting area, decorates the plot with labels, etc.

# %%
#importing matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# ##### Types of plot
#
# 1. Bar plot
# 2. Barh plot
# 3. Box plot
# 4. Hist plot
# 5. hist2d plot
# 6. pie plot
# 7. Line plot
# 8. Polar plot
# 9. Scatter plot
# 10. Stackplot plot
# 11. Stem plot
# 12. step plot
# 13. Quiver plot

# %% [markdown]
# ### Important function used in pyplot
#
# ###### Image functions
#
# - imread: used to read image from a file into an array
# - imsave: used to save an array as an image file
# - imshow: used to display an image on the axes
#
# ###### Axis function
#
# - Axes(): used to add axes to the figure
# - text(): adds text to the axes
# - title(): adds title to the selected axes
# - xlabel(): sets the x axia label
# - ylabel(): sets the y axis label
#
# ###### Figure function
# - figtext(): adds text to the figure
# - figure(): creates a  new figure
# - savefig(): save the current figure
# - show(): display a figure
# - close(): close the figure window

# %% [markdown]
# Figure:It is a whole figure which may contain one or more than one axes(plots). You can think of a figure as a canvas which contains plots.
#
# Axes: It is what we generally think of as a plot. A figure can contaiun many Axes. It contains two or three (in the case of 3D)Axix objects. Each Axes has a title, an x-label and a y-label.
#
# Axis: They are the number line like objects and take care of generating the graph limits.

# %%
x = [2,4,5]
y = [4,8,10]

#set figure size
plt.figure(figsize = (10,5))

plt.plot(x,y)
plt.title("My simple plot")
plt.xlabel("Weights (kg)")
plt.ylabel("Accelertion (m/s2kg)")

plt.show()

# %% [markdown]
# ##### Colors
#
# b - blue,
# g - green,
# r - red,
# c - cyan,
# m - magenta,
# y - yellow,
# k - black,
# w - white,
#
# ##### Symbols
#
# --
# .
# o
# ^
# +
# x
# D
# d
# 1
# 2
# 3
# 4
# h
# H
# p
# l

# %%
from matplotlib import style

style.use('ggplot')

x = [5,8,10]
y = [12,16,6]

x2 = [6,9,11]
y2 = [6,15,7]

plt.plot(x,y,'g',label='milo', linewidth = 5)
plt.plot(x2,y2,'c',label='Bournvita', linewidth = 5)

plt.title('Commodity Sales over time')
plt.ylabel('Price (N1000)')
plt.xlabel('Product (cartons)')

plt.legend()

plt.grid(True,color = 'k')

plt.show()

# %% [markdown]
# #### Exercises
#
# 1. Write a python program to draw a line with suitable label in the x axis, y axis and a title
# 2. Write a python program to draw a line using given axis values with suitable label in the x axis, y axis,and a title and a legend
# 3. Write a python program to draw line charts of the financial data of Alphabet Inc. between October 3, 2016 to October 7, 2016.
# Sample Financial data(fdata.csv):
# Date,Open,High,Low,Close
# 10-03-16,774.25,776.065002,769.5,772.559998
# 10-04-16,776.030029,778.710022,772.890015,776.429993
# 10-05-16,779.309998,782.070007,775.650024,776.469971
# 10-06-16,779,780.47998,775.539978,776.859985
# 10-07-16,779.659973,779.659973,770.75,775.080017
#
# 4. Write a python program to plot two or more lines with different styles, colors and linewidth.

# %%
# a python program to draw a line with suitable label in the x axis, y axis and a title

x = [1990,2000,2010,2020]
y = [5,7,3,15]

plt.plot(x,y)
plt.title("Child mortality Rate")
plt.xlabel("year(in decades)")
plt.ylabel("Rate(%)per decade")
plt.show()

# %%
'''a python program to draw a line using given axis 
values with suitable label in the x axis, y axis,and a title and a legend'''

# %%
#a python program to draw line charts of the financial data of Alphabet Inc.
import pandas as pd

ap = pd.read_csv("Alphabet_inc.csv")
print(ap)
print()

x = ["10-03-16","10-04-16","10-05-16","10-06-16","10-07-16"]
y = [774.25000,776.030029,779.309998,779.000000,779.659973]

y2 = [772.559998,776.429993,776.469971,776.859985,775.080017]

plt.title("financial data of Alphabet Inc. between October 3, 2016 to October 7, 2016")
plt.xlabel("Date of record")
plt.ylabel("Opening and closing stock price")


#plt.figure(figsize = ())

plt.plot(x,y, label = "Opening price")
plt.plot(x,y2, label = "closing price")

plt.legend()
plt.show()
# Out:
#        Date        Open        High         Low      Close
# 0  10-03-16  774.250000  776.065002  769.500000  772.559998
# 1  10-04-16  776.030029  778.710022  772.890015  776.429993
# 2  10-05-16  779.309998  782.070007  775.650024  776.469971
# 3  10-06-16  779.000000  780.479980  775.539978  776.859985
# 4  10-07-16  779.659973  779.659973  770.750000  775.080017

# %%
#a python program to draw line charts of the financial data of Alphabet Inc.(correction)

stock_data = pd.read_csv("Alphabet_inc.csv")
stock_data
# Out:
#        Date        Open        High         Low       Close
# 0  10-03-16  774.250000  776.065002  769.500000  772.559998
# 1  10-04-16  776.030029  778.710022  772.890015  776.429993
# 2  10-05-16  779.309998  782.070007  775.650024  776.469971
# 3  10-06-16  779.000000  780.479980  775.539978  776.859985
# 4  10-07-16  779.659973  779.659973  770.750000  775.080017

# %%
df = pd.DataFrame(stock_data)

ax = plt.gca() #get current axis
df.plot(kind = 'line', x = 'Date', y = 'Open', color = 'red', ax = ax)
df.plot(kind = 'line', x = 'Date', y = 'Close', color = 'blue', ax = ax)
plt.show()

# %%
#a python program to plot two or more lines with different styles, colors and linewidth.

x = [1999,2003,2007,2011,2015,2019]
y = [100,100,90,80,50,20]
y2 = [0,0,8,15,70,95]
y3 = [10,12,15,25,20,14]

#plt.figure(figsize =())

plt.title("Party Dominance(representation) per electoral term")
plt.xlabel("Electoral year(tenure beginning)")
plt.ylabel("Dominance(%)")

plt.plot(x,y,'m', label = "pdp", linewidth = 2)
plt.plot(x,y2,'c', label = "Apc", linewidth = 2)
plt.plot(x,y3,'r', label = "Apga", linewidth = 2)

plt.legend()

plt.show()
